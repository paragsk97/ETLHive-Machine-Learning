# %% [markdown]
# # Regularisation
#
# 1. Ridge (L2) - Penalty applied on Square of coefficients in loss function
# 2. Lasso (L1) - Penalty applied on absolute values of coefficients in loss function

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ## Step 1 - Data Ingestion

# %%
import pandas as pd 

df = pd.read_csv("Cars93.csv", na_values=["", "NA"], keep_default_na=False)

# %% [markdown]
# ## Target - Weight of the car

# %% [markdown]
# ## Step 2 - Perform basic data quality checks

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.shape
# Out:
# (94, 28)

# %%
df = df.drop_duplicates(keep="first").reset_index(drop=True)
df.shape
# Out:
# (93, 28)

# %%
m = df.isna().sum()
m
# Out:
# id                     0
# Manufacturer           0
# Model                  0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags                4
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         2
# Luggage.room          11
# Weight                 0
# Origin                 0
# Make                   0
# dtype: int64

# %%
m[m > 0]
# Out:
# AirBags            4
# Rear.seat.room     2
# Luggage.room      11
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  93 non-null     int64
#  1   Manufacturer        93 non-null     object
#  2   Model               93 non-null     object
#  3   Type                93 non-null     object
#  4   Min.Price           93 non-null     float64
#  5   Price               93 non-null     float64
#  6   Max.Price           93 non-null     float64
#  7   MPG.city            93 non-null     int64
#  8   MPG.highway         93 non-null     int64
#  9   AirBags             89 non-null     object
#  10  DriveTrain          93 non-null     object
#  11  Cylinders           93 non-null     object
#  12  EngineSize          93 non-null     float64
#  13  Horsepower          93 non-null     int64
#  14  RPM                 93 non-null     int64
#  15  Rev.per.mile        93 non-null     int64
#  16  Man.trans.avail     93 non-null     object
#  17  Fuel.tank.capacity  93 non-null     float64
#  18  Passengers          93 non-null     int64
#  19  Length              93 non-null     int64
#  20  Wheelbase           93 non-null     int64
#  21  Width               93 non-null     int64
#  22  Turn.circle         93 non-null     int64
#  23  Rear.seat.room      91 non-null     float64
#  24  Luggage.room        82 non-null     float64
#  25  Weight              93 non-null     int64
#  26  Origin              93 non-null     object
#  27  Make                93 non-null     object
# dtypes: float64(7), int64(12), object(9)
# memory usage: 20.5+ KB

# %% [markdown]
# ## Step 3 - Separate X and Y (Weight)
# and remove unnecessary columns

# %%
X = df.drop(columns = ["id", "Weight"])
Y = df["Weight"]

# %%
X.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8        25
# 1        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2         Audi       90  Compact       25.9   29.1       32.3        20
# 3         Audi      100  Midsize       30.8   37.7       44.6        19
# 4          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags DriveTrain  ... Fuel.tank.capacity  \
# 0           31                None      Front  ...               13.2
# 1           25  Driver & Passenger      Front  ...               18.0
# 2           26         Driver only      Front  ...               16.9
# 3           26                 NaN      Front  ...               21.1
# 4           30         Driver only       Rear  ...               21.1
#
#    Passengers  Length  Wheelbase  Width Turn.circle  Rear.seat.room  \
# 0           5     177        102     68          37            26.5
# 1           5     195        115     71          38            30.0
# 2           5     180        102     67          37            28.0
# 3           6     193        106     70          37            31.0
# 4           4     186        109     69          39            27.0
#
#    Luggage.room   Origin           Make
# 0          11.0  non-USA  Acura Integra
# 1          15.0  non-USA   Acura Legend
# 2          14.0  non-USA        Audi 90
# 3          17.0  non-USA       Audi 100
# 4          13.0  non-USA       BMW 535i
#
# [5 rows x 26 columns]

# %%
X.nunique()
# Out:
# Manufacturer          32
# Model                 93
# Type                   6
# Min.Price             79
# Price                 81
# Max.Price             79
# MPG.city              21
# MPG.highway           22
# AirBags                3
# DriveTrain             3
# Cylinders              6
# EngineSize            26
# Horsepower            57
# RPM                   24
# Rev.per.mile          78
# Man.trans.avail        2
# Fuel.tank.capacity    38
# Passengers             6
# Length                51
# Wheelbase             27
# Width                 16
# Turn.circle           14
# Rear.seat.room        24
# Luggage.room          16
# Origin                 2
# Make                  93
# dtype: int64

# %%
def get_high_cardinality(X : pd.DataFrame, threshold : float = 0.9) -> list[str]:
    unique_count = X.select_dtypes(include="object").nunique()
    cardinality = unique_count / len(X)
    print(cardinality)
    high_cardinality = cardinality[cardinality >= threshold]
    return high_cardinality.index.tolist()

# %%
high_card = get_high_cardinality(X)
# Out:
# Manufacturer       0.344086
# Model              1.000000
# Type               0.064516
# AirBags            0.032258
# DriveTrain         0.032258
# Cylinders          0.064516
# Man.trans.avail    0.021505
# Origin             0.021505
# Make               1.000000
# dtype: float64

# %%
high_card
# Out:
# ['Model', 'Make']

# %%
X = X.drop(columns=high_card)
X.head()
# Out:
#   Manufacturer     Type  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 0        Acura    Small       12.9   15.9       18.8        25           31
# 1        Acura  Midsize       29.2   33.9       38.7        18           25
# 2         Audi  Compact       25.9   29.1       32.3        20           26
# 3         Audi  Midsize       30.8   37.7       44.6        19           26
# 4          BMW  Midsize       23.7   30.0       36.2        22           30
#
#               AirBags DriveTrain Cylinders  ...  Man.trans.avail  \
# 0                None      Front         4  ...              Yes
# 1  Driver & Passenger      Front         6  ...              Yes
# 2         Driver only      Front         6  ...              Yes
# 3                 NaN      Front         6  ...              Yes
# 4         Driver only       Rear         4  ...              Yes
#
#    Fuel.tank.capacity  Passengers  Length Wheelbase  Width  Turn.circle  \
# 0                13.2           5     177       102     68           37
# 1                18.0           5     195       115     71           38
# 2                16.9           5     180       102     67           37
# 3                21.1           6     193       106     70           37
# 4                21.1           4     186       109     69           39
#
#    Rear.seat.room  Luggage.room   Origin
# 0            26.5          11.0  non-USA
# 1            30.0          15.0  non-USA
# 2            28.0          14.0  non-USA
# 3            31.0          17.0  non-USA
# 4            27.0          13.0  non-USA
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Step 4 - Apply Train test split first

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(
    X, Y, test_size=0.3, random_state=10
)

# %%
xtrain.head()
# Out:
#      Manufacturer     Type  Min.Price  Price  Max.Price  MPG.city  \
# 2            Audi  Compact       25.9   29.1       32.3        20
# 58  Mercedes-Benz  Midsize       43.8   61.9       80.0        19
# 67     Oldsmobile  Compact       13.0   13.5       14.0        24
# 76        Pontiac    Large       19.4   24.4       29.4        19
# 84         Toyota   Sporty       14.2   18.4       22.6        25
#
#     MPG.highway             AirBags DriveTrain Cylinders  ...  \
# 2            26         Driver only      Front         6  ...
# 58           25  Driver & Passenger       Rear         6  ...
# 67           31                None      Front         4  ...
# 76           28  Driver & Passenger      Front         6  ...
# 84           32         Driver only      Front         4  ...
#
#     Man.trans.avail  Fuel.tank.capacity  Passengers  Length Wheelbase  Width  \
# 2               Yes                16.9           5     180       102     67
# 58               No                18.5           5     187       110     69
# 67               No                15.2           5     188       103     67
# 76               No                18.0           6     177       111     74
# 84              Yes                15.9           4     174        99     69
#
#     Turn.circle  Rear.seat.room  Luggage.room   Origin
# 2            37            28.0          14.0  non-USA
# 58           37            27.0          15.0  non-USA
# 67           39            28.0          14.0      USA
# 76           43            30.5          18.0      USA
# 84           39            23.0          13.0  non-USA
#
# [5 rows x 24 columns]

# %%
ytrain.head()
# Out:
# 2     3375
# 58    3525
# 67    2910
# 76    3495
# 84    2950
# Name: Weight, dtype: int64

# %%
xtest.head()
# Out:
#    Manufacturer     Type  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 34         Ford   Sporty       12.8   14.0       15.2        24           30
# 90   Volkswagen   Sporty       22.9   23.3       23.7        18           25
# 3          Audi  Midsize       30.8   37.7       44.6        19           26
# 35         Ford      Van       14.5   19.9       25.3        15           20
# 19     Chrylser    Large       18.4   18.4       18.4        20           28
#
#                AirBags DriveTrain Cylinders  ...  Man.trans.avail  \
# 34         Driver only      Front         4  ...              Yes
# 90                None      Front         6  ...              Yes
# 3                  NaN      Front         6  ...              Yes
# 35         Driver only        4WD         6  ...              Yes
# 19  Driver & Passenger      Front         6  ...               No
#
#     Fuel.tank.capacity  Passengers  Length Wheelbase  Width  Turn.circle  \
# 34                15.5           4     179       103     70           38
# 90                18.5           4     159        97     66           36
# 3                 21.1           6     193       106     70           37
# 35                21.0           7     176       119     72           45
# 19                18.0           6     203       113     74           40
#
#     Rear.seat.room  Luggage.room   Origin
# 34            23.0          18.0      USA
# 90            26.0          15.0  non-USA
# 3             31.0          17.0  non-USA
# 35            30.0           NaN      USA
# 19            31.0          15.0      USA
#
# [5 rows x 24 columns]

# %%
ytest.head()
# Out:
# 34    2710
# 90    2810
# 3     3405
# 35    3735
# 19    3515
# Name: Weight, dtype: int64

# %%
xtrain.shape
# Out:
# (65, 24)

# %%
xtest.shape
# Out:
# (28, 24)

# %%
ytrain.shape
# Out:
# (65,)

# %%
ytest.shape
# Out:
# (28,)

# %% [markdown]
# ## Step 5 - Apply Preprocessing on X
#
# 1. Continous Feature -> SimpleImputer(strategy="mean).StandardScaler()
# 2. Categorical Feature -> SimpleImputer, OrdinalEncoder, StandardSclaer

# %%
cat = xtrain.select_dtypes(include="object").columns.tolist()
cat
# Out:
# ['Manufacturer',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin']

# %%
con = xtrain.select_dtypes(include="number").columns.tolist()
con
# Out:
# ['Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room']

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer

# %%
num_pipe = make_pipeline(
    SimpleImputer(strategy="mean"),
    StandardScaler()
)

# %%
cat_pipe = make_pipeline(
    SimpleImputer(strategy="most_frequent"),
    OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1),
    StandardScaler()
)

# %%
pre = ColumnTransformer(
    [
        ("num", num_pipe, con),
        ("cat", cat_pipe, cat)
    ]
).set_output(transform="pandas")

# %%
pre.fit(xtrain) # type: ignore
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Min.Price', 'Price', 'Max.Price', 'MPG.city',
#                                   'MPG.highway', 'EngineSize', 'Horsepower',
#                                   'RPM', 'Rev.per.mile', 'Fuel.tank.capacity',
#                                   'Passengers', 'Length', 'Wheelbase', 'Width',
#                                   'Turn.circle', 'Rear.seat.room',
#                                   'Luggage.room']),
#                                 ('cat',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1)),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Manufacturer', 'Type', 'AirBags',
#                                   'DriveTrain', 'Cylinders', 'Man.trans.avail',
#                                   'Origin'])])

# %%
# Transform train and test data
xtrain_pre = pre.transform(xtrain) # type: ignore
xtest_pre = pre.transform(xtest) # type: ignore

# %%
xtrain_pre.head()
# Out:
#     num__Min.Price  num__Price  num__Max.Price  num__MPG.city  \
# 2         0.973180    0.918836        0.840807      -0.412420
# 58        2.971937    4.162683        4.909037      -0.623502
# 67       -0.467264   -0.623969       -0.719961       0.431905
# 76        0.247375    0.454017        0.593472      -0.623502
# 84       -0.333269   -0.139370        0.013515       0.642986
#
#     num__MPG.highway  num__EngineSize  num__Horsepower  num__RPM  \
# 2          -0.586550         0.017007         0.448374  0.396313
# 58         -0.797190         0.385482         1.271144  0.396313
# 67          0.466648        -0.443588         0.137550  1.208943
# 76         -0.165271         0.938195         0.411807 -0.741368
# 84          0.677288        -0.535706        -0.228125  0.233787
#
#     num__Rev.per.mile  num__Fuel.tank.capacity  ...  num__Turn.circle  \
# 2           -0.066228                -0.011249  ...         -0.703519
# 58          -0.183633                 0.476189  ...         -0.703519
# 67           0.129446                -0.529151  ...         -0.072778
# 76          -1.465302                 0.323865  ...          1.188704
# 84           0.178365                -0.315897  ...         -0.072778
#
#     num__Rear.seat.room  num__Luggage.room  cat__Manufacturer  cat__Type  \
# 2              0.046397           0.013226          -1.564922  -1.342107
# 58            -0.302943           0.383566           0.391230  -0.147080
# 67             0.046397           0.013226           0.782461  -1.342107
# 76             0.919745           1.494585           0.912871  -0.744593
# 84            -1.700300          -0.357113           1.564922   1.047946
#
#     cat__AirBags  cat__DriveTrain  cat__Cylinders  cat__Man.trans.avail  \
# 2      -0.292449        -0.192961        0.932919              0.765092
# 58     -1.754693         1.598822        0.932919             -1.307032
# 67      1.169795        -0.192961       -0.799645             -1.307032
# 76     -1.754693        -0.192961        0.932919             -1.307032
# 84     -0.292449        -0.192961       -0.799645              0.765092
#
#     cat__Origin
# 2      1.114172
# 58     1.114172
# 67    -0.897527
# 76    -0.897527
# 84     1.114172
#
# [5 rows x 24 columns]

# %%
xtest_pre.head()
# Out:
#     num__Min.Price  num__Price  num__Max.Price  num__MPG.city  \
# 34       -0.489596   -0.574520       -0.617615       0.431905
# 90        0.638193    0.345229        0.107331      -0.834583
# 3         1.520326    1.769357        1.889847      -0.623502
# 35       -0.299770    0.008977        0.243792      -1.467826
# 19        0.135713   -0.139370       -0.344694      -0.412420
#
#     num__MPG.highway  num__EngineSize  num__Horsepower  num__RPM  \
# 34          0.256008        -0.719944        -0.593801  0.396313
# 90         -0.797190         0.017007         0.558077  0.883891
# 3          -0.586550         0.017007         0.448374  0.396313
# 35         -1.850388         0.201244        -0.045288 -0.741368
# 19         -0.165271         0.477601         0.100983  0.071261
#
#     num__Rev.per.mile  num__Fuel.tank.capacity  ...  num__Turn.circle  \
# 34           0.051176                -0.437756  ...         -0.388148
# 90           0.139230                 0.476189  ...         -1.018889
# 3            0.432742                 1.268274  ...         -0.703519
# 35          -0.457578                 1.237809  ...          1.819445
# 19          -0.633685                 0.323865  ...          0.242593
#
#     num__Rear.seat.room  num__Luggage.room  cat__Manufacturer  cat__Type  \
# 34            -1.700300       1.494585e+00          -0.521641   1.047946
# 90            -0.652282       3.835661e-01           1.695332   1.047946
# 3              1.094415       1.124245e+00          -1.564922  -0.147080
# 35             0.745075      -6.578554e-16          -0.521641   1.645460
# 19             1.094415       3.835661e-01          -1.825742  -0.744593
#
#     cat__AirBags  cat__DriveTrain  cat__Cylinders  cat__Man.trans.avail  \
# 34     -0.292449        -0.192961       -0.799645              0.765092
# 90      1.169795        -0.192961        0.932919              0.765092
# 3      -0.292449        -0.192961        0.932919              0.765092
# 35     -0.292449        -1.984744        0.932919              0.765092
# 19     -1.754693        -0.192961        0.932919             -1.307032
#
#     cat__Origin
# 34    -0.897527
# 90     1.114172
# 3      1.114172
# 35    -0.897527
# 19    -0.897527
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Step 5 - Model Building Experiment with different models
#
# 1. Baseline - Linear Regression
# 2. Apply Feature Selection - Linear Regression
# 3. Apply Lasso on Selected features
# 4. Apply Ridge on selected features
#
# ### Model 1 - Baseline Model LinearRegression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

baseline = LinearRegression()
scores = cross_val_score(baseline, xtrain_pre, ytrain, cv=5, scoring="r2")
scores
# Out:
# array([0.8928423 , 0.92570425, 0.88431367, 0.95944455, 0.87304994])

# %%
scores.mean()
# Out:
# np.float64(0.9070709417185455)

# %%
scores.std()
# Out:
# np.float64(0.03152133031547317)

# %%
# Fit the entire model
baseline.fit(xtrain_pre, ytrain)
# Out:
# LinearRegression()

# %%
baseline.intercept_
# Out:
# np.float64(3119.999999999998)

# %%
baseline.coef_
# Out:
# array([ 3.31205854e+03, -7.57247328e+03,  4.35140974e+03,  3.70953528e+01,
#        -1.34782465e+02, -1.20782071e+02,  3.04613391e+02, -1.04887931e+02,
#        -5.77770004e+01,  1.05892385e+02,  6.95542111e+00,  3.66115752e+01,
#         2.80157989e+02, -5.26075365e+01,  1.79045619e+01, -3.99693198e+01,
#         5.39937019e+01,  7.37436832e+00,  4.69993390e+01, -1.57019808e+01,
#        -5.72670603e+00,  1.43702833e+01,  3.24813948e+01,  5.92682822e+01])

# %%
# R2 score on train
r2_train = baseline.score(xtrain_pre, ytrain)
r2_train
# Out:
# 0.9735977057191415

# %%
# R2 score on test
r2_test = baseline.score(xtest_pre, ytest)
r2_test
# Out:
# 0.8531054380497081

# %%
# Generalization error
gen_err = r2_train - r2_test
gen_err
# Out:
# 0.12049226766943344

# %% [markdown]
# ### Create a function to save above results for each model

# %%
# Initializing a balnk results list
results = []

def evaluate_and_log_model(results, model, xtrain, ytrain, xtest, ytest, description):
    #Cross validation data on train
    scores = cross_val_score(model, xtrain, ytrain, cv=5, scoring="r2")
    mean_score = scores.mean().round(4)
    std_score = scores.std().round(4)
    #Fit the model
    model.fit(xtrain, ytrain)
    #Evaluate r2 score on train and test
    r2_train = round(model.score(xtrain, ytrain), 4)
    r2_test = round(model.score(xtest, ytest), 4)
    #Generalization error
    gen_err = round(r2_train - r2_test, 4)
    # Save above results in a dictionary
    r = {
        "description": description,
        "name":type(model).__name__,
        "cv_mean":mean_score,
        "cv_std":std_score,
        "r2_train" : r2_train,
        "r2_test": r2_test,
        "gen_err": gen_err
    }
    print(r)
    results.append(r)
    return model

# %%
baseline = evaluate_and_log_model(
    results, LinearRegression(), xtrain_pre, ytrain, xtest_pre, ytest, description="Baseline LinearRegression"
)
# Out:
# {'description': 'Baseline LinearRegression', 'name': 'LinearRegression', 'cv_mean': np.float64(0.9071), 'cv_std': np.float64(0.0315), 'r2_train': 0.9736, 'r2_test': 0.8531, 'gen_err': 0.1205}

# %%
results
# Out:
# [{'description': 'Baseline LinearRegression',
#   'name': 'LinearRegression',
#   'cv_mean': np.float64(0.9071),
#   'cv_std': np.float64(0.0315),
#   'r2_train': 0.9736,
#   'r2_test': 0.8531,
#   'gen_err': 0.1205}]

# %%
from sklearn.feature_selection import SequentialFeatureSelector

sel = SequentialFeatureSelector(
    LinearRegression(), n_features_to_select="auto", direction="backward"
)
sel.fit(xtrain_pre, ytrain)
# Out:
# SequentialFeatureSelector(direction='backward', estimator=LinearRegression())

# %%
sel_cols = sel.get_feature_names_out()
sel_cols
# Out:
# array(['num__Price', 'num__MPG.highway', 'num__EngineSize',
#        'num__Horsepower', 'num__RPM', 'num__Fuel.tank.capacity',
#        'num__Passengers', 'num__Wheelbase', 'num__Rear.seat.room',
#        'num__Luggage.room', 'cat__Type', 'cat__Origin'], dtype=object)

# %%
len(sel_cols)
# Out:
# 12

# %%
xtrain_pre_sel = sel.transform(xtrain_pre)
xtrain_pre_sel
# Out:
# array([[ 9.18836346e-01, -5.86550440e-01,  1.70065527e-02,
#          4.48374418e-01,  3.96313167e-01, -1.12485506e-02,
#         -1.80783587e-01, -3.48290386e-01,  4.63966313e-02,
#          1.32264167e-02, -1.34210679e+00,  1.11417203e+00],
#        [ 4.16268316e+00, -7.97190100e-01,  3.85481861e-01,
#          1.27114429e+00,  3.96313167e-01,  4.76188644e-01,
#         -1.80783587e-01,  8.83757238e-01, -3.02942710e-01,
#          3.83566084e-01, -1.47080196e-01,  1.11417203e+00],
#        [-6.23968845e-01,  4.66647864e-01, -4.43587582e-01,
#          1.37550245e-01,  1.20894269e+00, -5.29150569e-01,
#         -1.80783587e-01, -1.94284433e-01,  4.63966313e-02,
#          1.32264167e-02, -1.34210679e+00, -8.97527468e-01],
#        [ 4.54016833e-01, -1.65271118e-01,  9.38194823e-01,
#          4.11806868e-01, -7.41368165e-01,  3.23864520e-01,
#          7.98460843e-01,  1.03776319e+00,  9.19744985e-01,
#          1.49458509e+00, -7.44593493e-01, -8.97527468e-01],
#        [-1.39369779e-01,  6.77287524e-01, -5.35706409e-01,
#         -2.28125253e-01,  2.33787263e-01, -3.15896797e-01,
#         -1.16002802e+00, -8.10308245e-01, -1.70030008e+00,
#         -3.57113251e-01,  1.04794640e+00,  1.11417203e+00],
#        [ 1.07874643e-01, -5.86550440e-01,  1.67514544e+00,
#         -1.16002802e+00, -1.73434396e+00, -1.28273039e-01,
#         -1.46813225e+00,  4.50433101e-01,  1.11417203e+00],
#        [-5.64630184e-01, -5.86550440e-01, -1.08841937e+00,
#         -8.68057373e-01,  8.02627929e-01, -1.77820838e+00,
#         -1.16002802e+00, -1.42633206e+00, -3.09765744e+00,
#         -2.94949092e+00,  1.04794640e+00, -8.97527468e-01],
#        [ 1.43310474e+00, -5.86550440e-01,  9.38194823e-01,
#          2.28969119e-01, -1.39147178e+00,  4.45723819e-01,
#          7.98460843e-01,  7.29751285e-01,  7.45075314e-01,
#          1.86492476e+00, -1.47080196e-01, -8.97527468e-01],
#        [-1.05911903e+00,  8.87927185e-01, -9.04181718e-01,
#         -1.21544910e+00,  3.96313167e-01, -1.38216566e+00,
#         -1.16002802e+00, -1.73434396e+00, -6.52282052e-01,
#         -1.46813225e+00,  4.50433101e-01,  1.11417203e+00]])

# %%
xtest_pre_sel.shape
# Out:
# (28, 12)

# %%
model_feat_sel = evaluate_and_log_model(
    results, LinearRegression(), xtrain_pre_sel, ytrain, xtest_pre_sel, ytest, description="Featue selection on LinearRegression"
)
# Out:
# {'description': 'Featue selection on LinearRegression', 'name': 'LinearRegression', 'cv_mean': np.float64(0.9455), 'cv_std': np.float64(0.0185), 'r2_train': 0.9701, 'r2_test': 0.8676, 'gen_err': 0.1025}

# %%
results
# Out:
# [{'description': 'Baseline LinearRegression',
#   'name': 'LinearRegression',
#   'cv_mean': np.float64(0.9071),
#   'cv_std': np.float64(0.0315),
#   'r2_train': 0.9736,
#   'r2_test': 0.8531,
#   'gen_err': 0.1205},
#  {'description': 'Featue selection on LinearRegression',
#   'name': 'LinearRegression',
#   'cv_mean': np.float64(0.9455),
#   'cv_std': np.float64(0.0185),
#   'r2_train': 0.9701,
#   'r2_test': 0.8676,
#   'gen_err': 0.1025}]

# %% [markdown]
# ## Model 3 - Lidge on selected items

# %%
alphas_list = [0, 0 , 0.1, 1, 20, 50, 200, 500, 10000]

# %%
params = {
    "alpha":alphas_list
}
print(params)
# Out:
# {'alpha': [0, 0, 0.1, 1, 20, 50, 200, 500, 10000]}

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

gscv_ridge = GridSearchCV(Ridge(random_state=42), params, cv=5, scoring="r2")
gscv_ridge.fit(xtrain_pre_sel, ytrain) # Apply this on selected features only
# Out:
# GridSearchCV(cv=5, estimator=Ridge(random_state=42),
#              param_grid={'alpha': [0, 0, 0.1, 1, 20, 50, 200, 500, 10000]},
#              scoring='r2')

# %%
gscv_ridge.best_params_
# Out:
# {'alpha': 0.1}

# %%
gscv_ridge.best_score_
# Out:
# np.float64(0.9459654020956506)

# %%
best_ridge = gscv_ridge.best_estimator_
best_ridge
# Out:
# Ridge(alpha=0.1, random_state=42)

# %%
sel_ridge = evaluate_and_log_model(
    results, best_ridge, xtrain_pre_sel, ytrain, xtest_pre_sel, ytest,
    description="Ridge on Selected Features"
)
# Out:
# {'description': 'Ridge on Selected Features', 'name': 'Ridge', 'cv_mean': np.float64(0.946), 'cv_std': np.float64(0.0174), 'r2_train': 0.9701, 'r2_test': 0.8713, 'gen_err': 0.0988}

# %% [markdown]
# ## Model 4 - Lasso on Selected features

# %%
params
# Out:
# {'alpha': [0, 0, 0.1, 1, 20, 50, 200, 500, 10000]}

# %%
from sklearn.linear_model import Lasso

gscv_lasso = GridSearchCV(Lasso(random_state=42), params, cv=5, scoring="r2")
gscv_lasso.fit(xtrain_pre_sel, ytrain)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(random_state=42),
#              param_grid={'alpha': [0, 0, 0.1, 1, 20, 50, 200, 500, 10000]},
#              scoring='r2')

# %%
gscv_lasso.best_score_
# Out:
# np.float64(0.9463433605017105)

# %%
gscv_lasso.best_params_
# Out:
# {'alpha': 1}

# %%
best_lasso = gscv_lasso.best_estimator_
best_lasso
# Out:
# Lasso(alpha=1, random_state=42)

# %%
sel_lasso = evaluate_and_log_model(
    results, best_lasso, xtrain_pre_sel, ytrain, xtest_pre_sel, ytest,
    description="Lasso on Selected features"
)
# Out:
# {'description': 'Lasso on Selected features', 'name': 'Lasso', 'cv_mean': np.float64(0.9463), 'cv_std': np.float64(0.0175), 'r2_train': 0.9698, 'r2_test': 0.8812, 'gen_err': 0.0886}

# %%
results
# Out:
# [{'description': 'Baseline LinearRegression',
#   'name': 'LinearRegression',
#   'cv_mean': np.float64(0.9071),
#   'cv_std': np.float64(0.0315),
#   'r2_train': 0.9736,
#   'r2_test': 0.8531,
#   'gen_err': 0.1205},
#  {'description': 'Featue selection on LinearRegression',
#   'name': 'LinearRegression',
#   'cv_mean': np.float64(0.9455),
#   'cv_std': np.float64(0.0185),
#   'r2_train': 0.9701,
#   'r2_test': 0.8676,
#   'gen_err': 0.1025},
#  {'description': 'Ridge on Selected Features',
#   'name': 'Ridge',
#   'cv_mean': np.float64(0.946),
#   'cv_std': np.float64(0.0174),
#   'r2_train': 0.9701,
#   'r2_test': 0.8713,
#   'gen_err': 0.0988},
#  {'description': 'Lasso on Selected features',
#   'name': 'Lasso',
#   'cv_mean': np.float64(0.9463),
#   'cv_std': np.float64(0.0175),
#   'r2_train': 0.9698,
#   'r2_test': 0.8812,
#   'gen_err': 0.0886}]

# %% [markdown]
# ## Model 5 - Polynomial feature engineering with Ridge

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_ridge = make_pipeline(
    PolynomialFeatures(degree=2, include_bias=False),
    Ridge(random_state=42)
)

# %%
params2 = {
    "ridge__alpha":alphas_list
}

# %%
gscv_poly_ridge = GridSearchCV(poly_ridge, params2, cv=5, scoring="r2")
gscv_poly_ridge.fit(xtrain_pre_sel, ytrain)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('polynomialfeatures',
#                                         PolynomialFeatures(include_bias=False)),
#                                        ('ridge', Ridge(random_state=42))]),
#              param_grid={'ridge__alpha': [0, 0, 0.1, 1, 20, 50, 200, 500,
#                                           10000]},
#              scoring='r2')

# %%
gscv_poly_ridge.best_params_
# Out:
# {'ridge__alpha': 1}

# %%
gscv_poly_ridge.best_score_
# Out:
# np.float64(0.8553789684667203)

# %%
best_poly_ridge = gscv_poly_ridge.best_estimator_
best_poly_ridge
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(include_bias=False)),
#                 ('ridge', Ridge(alpha=1, random_state=42))])

# %%
sel_poly_ridge = evaluate_and_log_model(
    results, best_poly_ridge, xtrain_pre_sel, ytrain, xtest_pre_sel, ytest,
    description="Polynomial Ridge on Selected Features"
)
# Out:
# {'description': 'Polynomial Ridge on Selected Features', 'name': 'Pipeline', 'cv_mean': np.float64(0.8554), 'cv_std': np.float64(0.1209), 'r2_train': 0.996, 'r2_test': 0.832, 'gen_err': 0.164}

# %% [markdown]
# ## Model 6 Polynomial features with Lasso

# %%
poly_lasso = make_pipeline(
    PolynomialFeatures(degree=2, include_bias=False),
    Lasso(random_state=42)
)

# %%
param3 = {
    "lasso__alpha":alphas_list
}

# %%
gscv_poly_lasso = GridSearchCV(poly_lasso, param3, cv=5, scoring="r2")
gscv_poly_lasso.fit(xtrain_pre_sel, ytrain)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('polynomialfeatures',
#                                         PolynomialFeatures(include_bias=False)),
#                                        ('lasso', Lasso(random_state=42))]),
#              param_grid={'lasso__alpha': [0, 0, 0.1, 1, 20, 50, 200, 500,
#                                           10000]},
#              scoring='r2')

# %%
gscv_poly_lasso.best_params_
# Out:
# {'lasso__alpha': 20}

# %%
gscv_poly_lasso.best_score_
# Out:
# np.float64(0.9236681101347639)

# %%
best_poly_lasso = gscv_poly_lasso.best_estimator_
best_poly_lasso
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(include_bias=False)),
#                 ('lasso', Lasso(alpha=20, random_state=42))])

# %%
sel_poly_lasso = evaluate_and_log_model(
    results, best_poly_lasso, xtrain_pre_sel, ytrain, xtest_pre_sel, ytest,
    description="Poly Lasso on selected features"
)
# Out:
# {'description': 'Poly Lasso on selected features', 'name': 'Pipeline', 'cv_mean': np.float64(0.9237), 'cv_std': np.float64(0.0491), 'r2_train': 0.9656, 'r2_test': 0.939, 'gen_err': 0.0266}

# %%
results
# Out:
# [{'description': 'Baseline LinearRegression',
#   'name': 'LinearRegression',
#   'cv_mean': np.float64(0.9071),
#   'cv_std': np.float64(0.0315),
#   'r2_train': 0.9736,
#   'r2_test': 0.8531,
#   'gen_err': 0.1205},
#  {'description': 'Featue selection on LinearRegression',
#   'name': 'LinearRegression',
#   'cv_mean': np.float64(0.9455),
#   'cv_std': np.float64(0.0185),
#   'r2_train': 0.9701,
#   'r2_test': 0.8676,
#   'gen_err': 0.1025},
#  {'description': 'Ridge on Selected Features',
#   'name': 'Ridge',
#   'cv_mean': np.float64(0.946),
#   'cv_std': np.float64(0.0174),
#   'r2_train': 0.9701,
#   'r2_test': 0.8713,
#   'gen_err': 0.0988},
#  {'description': 'Lasso on Selected features',
#   'name': 'Lasso',
#   'cv_mean': np.float64(0.9463),
#   'cv_std': np.float64(0.0175),
#   'r2_train': 0.9698,
#   'r2_test': 0.8812,
#   'gen_err': 0.0886},
#  {'description': 'Polynomial Ridge on Selected Features',
#   'name': 'Pipeline',
#   'cv_mean': np.float64(0.8554),
#   'cv_std': np.float64(0.1209),
#   'r2_train': 0.996,
#   'r2_test': 0.832,
#   'gen_err': 0.164},
#  {'description': 'Poly Lasso on selected features',
#   'name': 'Pipeline',
#   'cv_mean': np.float64(0.9237),
#   'cv_std': np.float64(0.0491),
#   'r2_train': 0.9656,
#   'r2_test': 0.939,
#   'gen_err': 0.0266}]

# %%
res_df = pd.DataFrame(results)
res_df
# Out:
#                              description              name  cv_mean  cv_std  \
# 0              Baseline LinearRegression  LinearRegression   0.9071  0.0315
# 1   Featue selection on LinearRegression  LinearRegression   0.9455  0.0185
# 2             Ridge on Selected Features             Ridge   0.9460  0.0174
# 3             Lasso on Selected features             Lasso   0.9463  0.0175
# 4  Polynomial Ridge on Selected Features          Pipeline   0.8554  0.1209
# 5        Poly Lasso on selected features          Pipeline   0.9237  0.0491
#
#    r2_train  r2_test  gen_err
# 0    0.9736   0.8531   0.1205
# 1    0.9701   0.8676   0.1025
# 2    0.9701   0.8713   0.0988
# 3    0.9698   0.8812   0.0886
# 4    0.9960   0.8320   0.1640
# 5    0.9656   0.9390   0.0266

# %%
sort_df = res_df.sort_values(by="gen_err")
sort_df
# Out:
#                              description              name  cv_mean  cv_std  \
# 5        Poly Lasso on selected features          Pipeline   0.9237  0.0491
# 3             Lasso on Selected features             Lasso   0.9463  0.0175
# 2             Ridge on Selected Features             Ridge   0.9460  0.0174
# 1   Featue selection on LinearRegression  LinearRegression   0.9455  0.0185
# 0              Baseline LinearRegression  LinearRegression   0.9071  0.0315
# 4  Polynomial Ridge on Selected Features          Pipeline   0.8554  0.1209
#
#    r2_train  r2_test  gen_err
# 5    0.9656   0.9390   0.0266
# 3    0.9698   0.8812   0.0886
# 2    0.9701   0.8713   0.0988
# 1    0.9701   0.8676   0.1025
# 0    0.9736   0.8531   0.1205
# 4    0.9960   0.8320   0.1640

# %%
sort_df.to_csv("evaluation.csv", index=False)

# %% [markdown]
# ## Polynomial Lasso has lowest generalization error

# %%
# Evaluate in detail
from sklearn.metrics import (
    root_mean_squared_error,
    mean_absolute_error,
    mean_absolute_percentage_error,
    r2_score
)

def evaluate_model(model, x, y):
    #Predict results for x
    ypred = model.predict(x)
    # Get the metrices
    rmse = root_mean_squared_error(y, ypred)
    mae = mean_absolute_error(y, ypred)
    mape = mean_absolute_percentage_error(y, ypred)
    r2 = r2_score(y, ypred)
    # Print the results
    print(f"RMSE : {rmse:.2f}")
    print(f"MAE : {mae:.2f}")
    print(f"MAPE : {mape:.2%}")
    print(f"R2 : {r2:.2%}")

# %%
evaluate_model(sel_poly_lasso, xtrain_pre_sel, ytrain)
# Out:
# RMSE : 110.84
# MAE : 88.77
# MAPE : 2.95%
# R2 : 96.56%

# %%
evaluate_model(sel_poly_lasso, xtest_pre_sel, ytest)
# Out:
# RMSE : 134.59
# MAE : 102.07
# MAPE : 3.51%
# R2 : 93.90%

# %% [markdown]
# ## Out of Sample prediction

# %%
xnew = pd.read_csv("sample.csv", na_values=["","NA"], keep_default_na=False)
xnew
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Audi      100  Midsize       30.8   37.7       44.6        19
# 1      Pontiac  Sunbird  Compact        9.4   11.1       12.8        23
# 2    Chevrolet   Lumina  Midsize       13.4   15.9       18.4        21
# 3        Mazda     RX-7   Sporty       32.5   32.5       32.5        17
# 4   Volkswagen      Fox    Small        8.7    9.1        9.5        25
#
#    MPG.highway      AirBags DriveTrain  ... Fuel.tank.capacity  Passengers  \
# 0           26          NaN      Front  ...               15.0           6
# 1           31         None      Front  ...               15.2           5
# 2           29         None      Front  ...               16.5           6
# 3           25  Driver only       Rear  ...               20.0           2
# 4           33         None      Front  ...               12.4           4
#
#    Length  Wheelbase  Width Turn.circle  Rear.seat.room  Luggage.room  \
# 0     190        106     65          37            31.0          17.0
# 1     181        101     66          39            25.0          13.0
# 2     198        108     71          40            28.5          16.0
# 3     169         96     69          37             NaN           NaN
# 4     163         93     63          34            26.0          10.0
#
#     Origin              Make
# 0  non-USA          Audi 100
# 1      USA   Pontiac Sunbird
# 2      USA  Chevrolet Lumina
# 3  non-USA        Mazda RX-7
# 4  non-USA    Volkswagen Fox
#
# [5 rows x 26 columns]

# %%
xnew_pre = pre.transform(xnew) # type: ignore
xnew_pre
# Out:
#    num__Min.Price  num__Price  num__Max.Price  num__MPG.city  \
# 0        1.520326    1.769357        1.889847      -0.623502
# 1       -0.869249   -0.861323       -0.822306       0.220823
# 2       -0.422599   -0.386614       -0.344694      -0.201339
# 3        1.710152    1.255089        0.857864      -1.045664
# 4       -0.947412   -1.059119       -1.103756       0.642986
#
#    num__MPG.highway  num__EngineSize  num__Horsepower  num__RPM  \
# 0         -0.586550         0.017007         0.448374  0.396313
# 1          0.466648        -0.719944        -0.685220 -0.091265
# 2          0.045369        -0.535706        -0.685220 -0.091265
# 3         -0.797190        -1.364776         1.965928  2.021572
# 4          0.887927        -0.904182        -1.215449  0.396313
#
#    num__Rev.per.mile  num__Fuel.tank.capacity  ...  num__Turn.circle  \
# 0           0.432742                -0.590080  ...         -0.703519
# 1           0.687119                -0.529151  ...         -0.072778
# 2           0.550147                -0.133108  ...          0.242593
# 3           0.021825                 0.933161  ...         -0.703519
# 4           0.462093                -1.382166  ...         -1.649630
#
#    num__Rear.seat.room  num__Luggage.room  cat__Manufacturer  cat__Type  \
# 0             1.094415       1.124245e+00          -1.564922  -0.147080
# 1            -1.001621      -3.571133e-01           0.912871  -1.342107
# 2             0.221066       7.539058e-01          -1.043281  -0.147080
# 3             0.000000      -6.578554e-16           0.260820   1.047946
# 4            -0.652282      -1.468132e+00           1.695332   0.450433
#
#    cat__AirBags  cat__DriveTrain  cat__Cylinders  cat__Man.trans.avail  \
# 0     -0.292449        -0.192961        0.932919              0.765092
# 1      1.169795        -0.192961       -0.799645              0.765092
# 2      1.169795        -0.192961       -0.799645             -1.307032
# 3     -0.292449         1.598822       -2.532208              0.765092
# 4      1.169795        -0.192961       -0.799645              0.765092
#
#    cat__Origin
# 0     1.114172
# 1    -0.897527
# 2    -0.897527
# 3     1.114172
# 4     1.114172
#
# [5 rows x 24 columns]

# %%
xnew_pre_sel = sel.transform(xnew_pre)
xnew_pre_sel
# Out:
# array([[ 1.76935716e+00, -5.86550440e-01,  1.70065527e-02,
#          4.48374418e-01,  3.96313167e-01, -5.90080219e-01,
#          7.98460843e-01,  2.67733426e-01,  1.09441466e+00,
#          1.12424542e+00, -1.47080196e-01,  1.11417203e+00],
#        [-8.61323490e-01,  4.66647864e-01, -7.19944064e-01,
#         -6.85219624e-01, -9.12645464e-02, -5.29150569e-01,
#         -1.80783587e-01, -5.02296339e-01, -1.00162139e+00,
#         -3.57113251e-01, -1.34210679e+00, -8.97527468e-01],
#        [-3.86614200e-01,  4.53685423e-02, -5.35706409e-01,
#         -6.85219624e-01, -9.12645464e-02, -1.33107849e-01,
#          7.98460843e-01,  5.75745332e-01,  2.21066302e-01,
#          7.53905752e-01, -1.47080196e-01, -8.97527468e-01],
#        [ 1.25508876e+00, -7.97190100e-01, -1.36477585e+00,
#          1.96592773e+00,  2.02157221e+00,  9.33161013e-01,
#         -3.11851688e+00, -1.27232610e+00,  0.00000000e+00,
#         -6.57855402e-16,  1.04794640e+00,  1.11417203e+00],
#        [-1.05911903e+00,  8.87927185e-01, -9.04181718e-01,
#         -1.21544910e+00,  3.96313167e-01, -1.38216566e+00,
#         -1.16002802e+00, -1.73434396e+00, -6.52282052e-01,
#         -1.46813225e+00,  4.50433101e-01,  1.11417203e+00]])

# %%
preds = sel_poly_lasso.predict(xnew_pre_sel)
preds
# Out:
# array([3222.70292996, 2720.65588383, 3121.04886586, 3084.3663738 ,
#        2230.09853642])

# %%
xnew["Weight_pred"] = preds.round(2)
xnew
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Audi      100  Midsize       30.8   37.7       44.6        19
# 1      Pontiac  Sunbird  Compact        9.4   11.1       12.8        23
# 2    Chevrolet   Lumina  Midsize       13.4   15.9       18.4        21
# 3        Mazda     RX-7   Sporty       32.5   32.5       32.5        17
# 4   Volkswagen      Fox    Small        8.7    9.1        9.5        25
#
#    MPG.highway      AirBags DriveTrain  ... Passengers  Length  Wheelbase  \
# 0           26          NaN      Front  ...          6     190        106
# 1           31         None      Front  ...          5     181        101
# 2           29         None      Front  ...          6     198        108
# 3           25  Driver only       Rear  ...          2     169         96
# 4           33         None      Front  ...          4     163         93
#
#    Width  Turn.circle Rear.seat.room  Luggage.room   Origin              Make  \
# 0     65           37           31.0          17.0  non-USA          Audi 100
# 1     66           39           25.0          13.0      USA   Pontiac Sunbird
# 2     71           40           28.5          16.0      USA  Chevrolet Lumina
# 3     69           37            NaN           NaN  non-USA        Mazda RX-7
# 4     63           34           26.0          10.0  non-USA    Volkswagen Fox
#
#    Weight_pred
# 0      3222.70
# 1      2720.66
# 2      3121.05
# 3      3084.37
# 4      2230.10
#
# [5 rows x 27 columns]

# %%
xnew.to_csv("results.csv", index=False)

# %% [markdown]
# ## Save pre, sel, model

# %%
import joblib

joblib.dump(pre, "pre.joblib")
# Out:
# ['pre.joblib']

# %%
joblib.dump(sel, "sel.joblib")
# Out:
# ['sel.joblib']

# %%
joblib.dump(sel_poly_lasso, "poly_lasso.joblib")
# Out:
# ['poly_lasso.joblib']

# %%
p = joblib.load("pre.joblib")
p
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Min.Price', 'Price', 'Max.Price', 'MPG.city',
#                                   'MPG.highway', 'EngineSize', 'Horsepower',
#                                   'RPM', 'Rev.per.mile', 'Fuel.tank.capacity',
#                                   'Passengers', 'Length', 'Wheelbase', 'Width',
#                                   'Turn.circle', 'Rear.seat.room',
#                                   'Luggage.room']),
#                                 ('cat',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1)),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Manufacturer', 'Type', 'AirBags',
#                                   'DriveTrain', 'Cylinders', 'Man.trans.avail',
#                                   'Origin'])])

# %%
m = joblib.load("sel.joblib")
m
# Out:
# SequentialFeatureSelector(direction='backward', estimator=LinearRegression())

# %%
m = joblib.load("poly_lasso.joblib")
m
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(include_bias=False)),
#                 ('lasso', Lasso(alpha=20, random_state=42))])
