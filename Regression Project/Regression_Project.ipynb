# %% [markdown]
# ## Step 1 - Data Ingestion

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
import pandas as pd
df = pd.read_csv("training_set.csv", na_values=["","NA"], keep_default_na=False)

# %% [markdown]
# ## Target is SalesPrice

# %% [markdown]
# ## Step 2 - Perform Basic Data Quality Checks

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (1460, 81)

# %%
df = df.drop_duplicates(keep="first").reset_index(drop=True)
df.shape
# Out:
# (1460, 81)

# %%
m = df.isna().sum()
m
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
m[m > 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %% [markdown]
# ## Step 3 - Separate X and Y (SalesPrice)
# and remove unneccessary columns

# %%
X = df.drop(columns = ["Id","SalePrice"])
Y = df["SalePrice"]

# %%
X.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 1         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
# 2         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 3         Lvl    AllPub    Corner  ...           0        0    NaN   NaN
# 4         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0         NaN       0       2    2008        WD         Normal
# 1         NaN       0       5    2007        WD         Normal
# 2         NaN       0       9    2008        WD         Normal
# 3         NaN       0       2    2006        WD        Abnorml
# 4         NaN       0      12    2008        WD         Normal
#
# [5 rows x 79 columns]

# %%
Y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
X.nunique()
# Out:
# MSSubClass         15
# MSZoning            5
# LotFrontage       110
# LotArea          1073
# Street              2
#                  ...
# MiscVal            21
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# Length: 79, dtype: int64

# %%
Y.nunique()
# Out:
# 663

# %%
def get_high_cardinality(X : pd.DataFrame, threshold : float = 0.9) -> list[str]:
    unique_count = X.select_dtypes(include="object").nunique()
    cardinality = unique_count / len(X)
    print(cardinality)
    high_cardinality = cardinality[cardinality >= threshold]
    return high_cardinality.index.tolist()

# %%
high_card = get_high_cardinality(X)
# Out:
# MSZoning         0.003425
# Street           0.001370
# Alley            0.001370
# LotShape         0.002740
# LandContour      0.002740
# Utilities        0.001370
# LotConfig        0.003425
# LandSlope        0.002055
# Neighborhood     0.017123
# Condition1       0.006164
# Condition2       0.005479
# BldgType         0.003425
# HouseStyle       0.005479
# RoofStyle        0.004110
# RoofMatl         0.005479
# Exterior1st      0.010274
# Exterior2nd      0.010959
# MasVnrType       0.002740
# ExterQual        0.002740
# ExterCond        0.003425
# Foundation       0.004110
# BsmtQual         0.002740
# BsmtCond         0.002740
# BsmtExposure     0.002740
# BsmtFinType1     0.004110
# BsmtFinType2     0.004110
# Heating          0.004110
# HeatingQC        0.003425
# CentralAir       0.001370
# Electrical       0.003425
# KitchenQual      0.002740
# Functional       0.004795
# FireplaceQu      0.003425
# GarageType       0.004110
# GarageFinish     0.002055
# GarageQual       0.003425
# GarageCond       0.003425
# PavedDrive       0.002055
# PoolQC           0.002055
# Fence            0.002740
# MiscFeature      0.002740
# SaleType         0.006164
# SaleCondition    0.004110
# dtype: float64

# %%
high_card
# Out:
# []

# %%
X = X.drop(columns=high_card)
X.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 1         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
# 2         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 3         Lvl    AllPub    Corner  ...           0        0    NaN   NaN
# 4         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0         NaN       0       2    2008        WD         Normal
# 1         NaN       0       5    2007        WD         Normal
# 2         NaN       0       9    2008        WD         Normal
# 3         NaN       0       2    2006        WD        Abnorml
# 4         NaN       0      12    2008        WD         Normal
#
# [5 rows x 79 columns]

# %% [markdown]
# ## Step 4 - Apply Train test split first

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(
    X, Y, test_size=0.3, random_state=10
)

# %%
xtrain.head()
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 912          30       RM         51.0     6120   Pave   NaN      Reg
# 373          20       RL         79.0    10634   Pave   NaN      Reg
# 20           60       RL        101.0    14215   Pave   NaN      IR1
# 800          60       RL         79.0    12798   Pave   NaN      IR1
# 152          60       RL          NaN    14803   Pave   NaN      IR1
#
#     LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# 912         Lvl    AllPub    Inside  ...         120        0    NaN  MnPrv
# 373         Lvl    AllPub    Inside  ...           0        0    NaN   GdWo
# 20          Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 800         HLS    AllPub    Inside  ...           0        0    NaN    NaN
# 152         Lvl    AllPub   CulDSac  ...           0        0    NaN   GdWo
#
#     MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 912        Shed     620       7    2006        WD        Abnorml
# 373         NaN       0      11    2009        WD         Normal
# 20          NaN       0      11    2006       New        Partial
# 800        Shed     400       5    2008        WD         Normal
# 152         NaN       0       6    2006        WD         Normal
#
# [5 rows x 79 columns]

# %%
ytrain.head()
# Out:
# 912     88000
# 373    123000
# 20     325300
# 800    200000
# 152    190000
# Name: SalePrice, dtype: int64

# %%
xtest.head()
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 854          20       RL        102.0    17920   Pave   NaN      Reg
# 381          20       FV         60.0     7200   Pave  Pave      Reg
# 816          20       RL          NaN    11425   Pave   NaN      IR1
# 577          80       RL         96.0    11777   Pave   NaN      IR1
# 35           60       RL        108.0    13418   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 854         Lvl    AllPub    Inside  ...         312        0    NaN   NaN
# 381         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 816         Lvl    AllPub    Corner  ...           0        0    NaN   NaN
# 577         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 35          Lvl    AllPub    Inside  ...           0        0    NaN   NaN
#
#     MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 854         NaN       0       7    2006        WD        Abnorml
# 381         NaN       0       8    2006       New        Partial
# 816         NaN       0       7    2006        WD         Normal
# 577         NaN       0       5    2006        WD        Abnorml
# 35          NaN       0       9    2006        WD         Normal
#
# [5 rows x 79 columns]

# %%
ytest.head()
# Out:
# 854    170000
# 381    187750
# 816    137000
# 577    164500
# 35     309000
# Name: SalePrice, dtype: int64

# %%
xtrain.shape
# Out:
# (1022, 79)

# %%
xtest.shape
# Out:
# (438, 79)

# %%
ytrain.shape
# Out:
# (1022,)

# %%
ytest.shape
# Out:
# (438,)

# %% [markdown]
# ## Step 5 - Apply Preprocessing on X
#
# 1. Continous Feature -> SimpleImputer(strategy="mean).StandardScaler()
# 2. Categorical Feature -> SimpleImputer, OrdinalEncoder, StandardSclaer

# %%
cat = xtrain.select_dtypes(include="object").columns.tolist()
cat
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
con = xtrain.select_dtypes(include="number").columns.tolist()
con
# Out:
# ['MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer

# %%
num_pipe = make_pipeline(
    SimpleImputer(strategy="mean"),
    StandardScaler()
)

# %%
cat_pipe = make_pipeline(
    SimpleImputer(strategy="most_frequent"),
    OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1),
    StandardScaler()
)

# %%
pre = ColumnTransformer(
    [
        ("num", num_pipe, con),
        ("cat", cat_pipe, cat)
    ]
).set_output(transform="pandas")

# %%
pre.fit(xtrain) # type: ignore
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['MSSubClass', 'LotFrontage', 'LotArea',
#                                   'OverallQual', 'OverallCond', 'YearBuilt',
#                                   'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#                                   'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#                                   '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#                                   'GrLivArea', 'BsmtFullBath', '...
#                                  ['MSZoning', 'Street', 'Alley', 'LotShape',
#                                   'LandContour', 'Utilities', 'LotConfig',
#                                   'LandSlope', 'Neighborhood', 'Condition1',
#                                   'Condition2', 'BldgType', 'HouseStyle',
#                                   'RoofStyle', 'RoofMatl', 'Exterior1st',
#                                   'Exterior2nd', 'MasVnrType', 'ExterQual',
#                                   'ExterCond', 'Foundation', 'BsmtQual',
#                                   'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#                                   'BsmtFinType2', 'Heating', 'HeatingQC',
#                                   'CentralAir', 'Electrical', ...])])

# %%
# Transform train and test data
xtrain_pre = pre.transform(xtrain) # type: ignore
xtest_pre = pre.transform(xtest) # type: ignore

# %%
xtrain_pre.head()
# Out:
#      num__MSSubClass  num__LotFrontage  num__LotArea  num__OverallQual  \
# 912        -0.637138         -0.832375     -0.403687         -0.832137
# 373        -0.872425          0.381056     -0.004215         -0.832137
# 20          0.068721          1.334466      0.312690          1.354094
# 800         0.068721          0.381056      0.187291         -0.103393
# 152         0.068721          0.000000      0.364725         -0.103393
#
#      num__OverallCond  num__YearBuilt  num__YearRemodAdd  num__MasVnrArea  \
# 912          1.322374       -1.536211          -1.693863        -0.574378
# 373          0.402383       -0.612735          -1.548422        -0.574378
# 20          -0.517607        1.102291           1.021023         1.463540
# 800         -0.517607        0.838441           0.584702        -0.574378
# 152         -0.517607       -0.019072          -0.675780         0.777083
#
#      num__BsmtFinSF1  num__BsmtFinSF2  ...  cat__GarageType  \
# 912         0.089078        -0.272009  ...         1.596608
# 373        -0.041272         0.926265  ...        -0.680759
# 20         -0.955862        -0.272009  ...         0.457925
# 800         0.031382        -0.272009  ...        -0.680759
# 152        -0.066915        -0.272009  ...        -0.680759
#
#      cat__GarageFinish  cat__GarageQual  cat__GarageCond  cat__PavedDrive  \
# 912           0.971066         0.209088         0.187974         0.281373
# 373           0.971066         0.209088         0.187974         0.281373
# 20           -0.258710         0.209088         0.187974         0.281373
# 800          -0.258710         0.209088         0.187974         0.281373
# 152          -0.258710         0.209088         0.187974         0.281373
#
#      cat__PoolQC  cat__Fence  cat__MiscFeature  cat__SaleType  \
# 912     0.044281    0.265798          0.059456       0.319937
# 373     0.044281   -1.924895          0.059456       0.319937
# 20      0.044281    0.265798          0.059456      -0.952342
# 800     0.044281    0.265798          0.059456       0.319937
# 152     0.044281   -1.924895          0.059456       0.319937
#
#      cat__SaleCondition
# 912           -3.386035
# 373            0.206519
# 20             1.104658
# 800            0.206519
# 152            0.206519
#
# [5 rows x 79 columns]

# %%
xtest_pre.head()
# Out:
#      num__MSSubClass  num__LotFrontage  num__LotArea  num__OverallQual  \
# 854        -0.872425          1.377803      0.640568         -0.832137
# 381        -0.872425         -0.442343     -0.308111          0.625350
# 816        -0.872425          0.000000      0.065785         -0.832137
# 577         0.539294          1.117782      0.096936         -0.832137
# 35          0.068721          1.637824      0.242158          1.354094
#
#      num__OverallCond  num__YearBuilt  num__YearRemodAdd  num__MasVnrArea  \
# 854         -1.437597       -0.546773          -0.530340        -0.574378
# 381         -0.517607        1.135273           1.021023        -0.574378
# 816          0.402383       -0.579754          -1.499942        -0.574378
# 577          0.402383       -0.183979          -0.918181        -0.054173
# 35          -0.517607        1.069310           0.972543         0.133530
#
#      num__BsmtFinSF1  num__BsmtFinSF2  ...  cat__GarageType  \
# 854        -0.301973         6.950921  ...        -0.680759
# 381        -0.955862        -0.272009  ...        -0.680759
# 816         0.082668        -0.272009  ...        -0.680759
# 577        -0.254961         3.396042  ...        -0.680759
# 35         -0.955862        -0.272009  ...         0.457925
#
#      cat__GarageFinish  cat__GarageQual  cat__GarageCond  cat__PavedDrive  \
# 854           0.971066         0.209088         0.187974         0.281373
# 381          -0.258710         0.209088         0.187974         0.281373
# 816          -0.258710         0.209088         0.187974         0.281373
# 577          -0.258710         0.209088         0.187974         0.281373
# 35           -1.488486         0.209088         0.187974         0.281373
#
#      cat__PoolQC  cat__Fence  cat__MiscFeature  cat__SaleType  \
# 854     0.044281    0.265798          0.059456       0.319937
# 381     0.044281    0.265798          0.059456      -0.952342
# 816     0.044281    0.265798          0.059456       0.319937
# 577     0.044281    0.265798          0.059456       0.319937
# 35      0.044281    0.265798          0.059456       0.319937
#
#      cat__SaleCondition
# 854           -3.386035
# 381            1.104658
# 816            0.206519
# 577           -3.386035
# 35             0.206519
#
# [5 rows x 79 columns]

# %% [markdown]
# ## Step 5 - Model Building Experiment with different models
#
# 1. Baseline - Linear Regression
# 2. Apply Feature Selection - Linear Regression
# 3. Apply Ridge on selected features
# 4. Apply Lasso on Selected Features
#
# ### Model 1 - Baseline Model Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

baseline = LinearRegression()
scores = cross_val_score(baseline, xtrain_pre, ytrain, cv=5, scoring="r2")
scores
# Out:
# array([0.84232872, 0.65198776, 0.58207534, 0.70829589, 0.83149358])

# %%
scores.mean()
# Out:
# np.float64(0.7232362566095751)

# %%
scores.std()
# Out:
# np.float64(0.10112233089435309)

# %%
# Fit the entire model
baseline.fit(xtrain_pre, ytrain)
# Out:
# LinearRegression()

# %%
baseline.intercept_
# Out:
# np.float64(182072.7573385518)

# %%
baseline.coef_
# Out:
# array([ -5949.74977644,  -4861.8747776 ,   4536.59598823,  15303.15713677,
#          5872.85440248,   5794.74998719,   -545.77295183,   6048.06168464,
#           414.03044915,    756.86371909,   -753.06267389,    -58.53852841,
#          6858.43927252,   9892.24841712,  -1731.40379546,  12977.46723053,
#          3874.20509889,   -588.19350326,   1637.41282806,  -2074.60774999,
#         -1411.41044128,  -2841.81748307,   6870.34167907,   3661.33845843,
#           671.99134685,   9419.12213844,  -1577.22504595,   3060.72635778,
#            29.49407048,   -501.44172864,   1293.7419893 ,   2649.0416879 ,
#         -4754.51664829,    276.55979782,     21.73001652,   -910.38304245,
#         -1142.05684275,   3131.1476983 ,   -254.5349447 ,  -2023.90053353,
#          3094.35939288,  -1895.12025886,   -688.59384397,   2665.42922876,
#          3223.13474035,   -527.38746262,  -2412.40682958,  -1670.26881753,
#         -2290.93325479,   1287.40496926,   5913.56182776,  -3263.44706654,
#          1907.50968236,   2161.32327111,  -5800.66739587,    117.88808285,
#           380.18947965,  -8240.50791403,   3060.70974914,  -4320.65884536,
#         -3154.39800751,   1202.07925095,   -396.11069293,  -1218.66583733,
#           514.85047375,  -1212.20304737,  -8161.49076682,   1921.61789687,
#         -2848.80146483,  -1725.54879486,   -367.9709341 ,   -461.11062949,
#          -261.93715676,    667.97957563, -10376.14770135,    830.26447573,
#           290.34351805,  -1295.34531287,   3489.06562629])

# %%
# R2 score on train
r2_train = baseline.score(xtrain_pre, ytrain)
r2_train
# Out:
# 0.8576026905597295

# %%
# R2 score on test
r2_test = baseline.score(xtest_pre, ytest)
r2_test
# Out:
# 0.6973680771486954

# %%
# Generalization error
gen_err = r2_train - r2_test
gen_err
# Out:
# 0.16023461341103407

# %% [markdown]
# ### Create a function to save above results for each model

# %%
# Initializing a balnk results list
results = []

def evaluate_and_log_model(results, model, xtrain, ytrain, xtest, ytest, description):
    #Cross validation data on train
    scores = cross_val_score(model, xtrain, ytrain, cv=5, scoring="r2")
    mean_score = scores.mean().round(4)
    std_score = scores.std().round(4)
    #Fit the model
    model.fit(xtrain, ytrain)
    #Evaluate r2 score on train and test
    r2_train = round(model.score(xtrain, ytrain), 4)
    r2_test = round(model.score(xtest, ytest), 4)
    #Generalization error
    gen_err = round(r2_train - r2_test, 4)
    # Save above results in a dictionary
    r = {
        "description": description,
        "name":type(model).__name__,
        "cv_mean":mean_score,
        "cv_std":std_score,
        "r2_train" : r2_train,
        "r2_test": r2_test,
        "gen_err": gen_err
    }
    print(r)
    results.append(r)
    return model

# %%
baseline = evaluate_and_log_model(
    results, LinearRegression(), xtrain_pre, ytrain, xtest_pre, ytest, description="Baseline Linear Regression"
)
# Out:
# {'description': 'Baseline Linear Regression', 'name': 'LinearRegression', 'cv_mean': np.float64(0.7232), 'cv_std': np.float64(0.1011), 'r2_train': 0.8576, 'r2_test': 0.6974, 'gen_err': 0.1602}

# %% [markdown]
# ### Model 2 - Feature Selection on Linear Regression

# %%
from sklearn.feature_selection import SequentialFeatureSelector

sel = SequentialFeatureSelector(
    LinearRegression(), n_features_to_select="auto", direction="forward"
)
sel.fit(xtrain_pre, ytrain)
# Out:
# SequentialFeatureSelector(estimator=LinearRegression())

# %%
sel_cols = sel.get_feature_names_out()
sel_cols
# Out:
# array(['num__MSSubClass', 'num__LotArea', 'num__OverallQual',
#        'num__OverallCond', 'num__YearBuilt', 'num__LowQualFinSF',
#        'num__GrLivArea', 'num__BsmtFullBath', 'num__HalfBath',
#        'num__KitchenAbvGr', 'num__Fireplaces', 'num__GarageCars',
#        'num__ScreenPorch', 'num__YrSold', 'cat__Street', 'cat__Alley',
#        'cat__LotShape', 'cat__LandContour', 'cat__Utilities',
#        'cat__LandSlope', 'cat__Neighborhood', 'cat__HouseStyle',
#        'cat__RoofStyle', 'cat__RoofMatl', 'cat__Exterior2nd',
#        'cat__ExterQual', 'cat__BsmtQual', 'cat__BsmtCond',
#        'cat__BsmtExposure', 'cat__BsmtFinType1', 'cat__Heating',
#        'cat__HeatingQC', 'cat__CentralAir', 'cat__KitchenQual',
#        'cat__Functional', 'cat__FireplaceQu', 'cat__GarageQual',
#        'cat__GarageCond', 'cat__SaleCondition'], dtype=object)

# %%
len(sel_cols)
# Out:
# 39

# %%
xtrain_pre_sel = sel.transform(xtrain_pre)
xtrain_pre_sel
# Out:
# array([[-0.63713842, -0.40368676, -0.83213659, ...,  0.20908829,
#          0.18797359, -3.38603512],
#        [-0.87242495, -0.00421508, -0.83213659, ...,  0.20908829,
#          0.18797359,  0.20651914],
#        [ 0.06872116,  0.31268967,  1.35409374, ...,  0.20908829,
#          0.18797359,  1.10465771],
#        ...,
#        [ 0.06872116,  0.37755736,  2.08283718, ...,  0.20908829,
#          0.18797359,  1.10465771],
#        [ 0.30400769, -0.14881781,  0.62535029, ...,  0.20908829,
#          0.18797359,  0.20651914],
#        [ 0.06872116,  0.03392676,  1.35409374, ...,  0.20908829,
#          0.18797359,  1.10465771]], shape=(1022, 39))

# %%
xtrain_pre_sel.shape
# Out:
# (1022, 39)

# %%
xtest_pre_sel =sel.transform(xtest_pre)
xtest_pre_sel
# Out:
# array([[-8.72424952e-01,  6.40567958e-01, -8.32136593e-01, ...,
#          2.09088285e-01,  1.87973592e-01, -3.38603512e+00],
#        [-8.72424952e-01, -3.08110908e-01,  6.25350293e-01, ...,
#          2.09088285e-01,  1.87973592e-01,  1.10465771e+00],
#        [-8.72424952e-01,  6.57853805e-02, -8.32136593e-01, ...,
#          2.09088285e-01,  1.87973592e-01,  2.06519142e-01],
#        ...,
#        [ 3.12744604e+00,  8.34846130e-02, -8.32136593e-01, ...,
#          2.09088285e-01,  1.87973592e-01,  2.06519142e-01],
#        [-1.66565366e-01, -3.21253194e-04,  1.35409374e+00, ...,
#          2.09088285e-01,  1.87973592e-01,  2.06519142e-01],
#        [-1.66565366e-01, -4.14306303e-01, -8.32136593e-01, ...,
#          2.09088285e-01,  1.87973592e-01,  2.06519142e-01]],
#       shape=(438, 39))

# %%
xtest_pre_sel.shape
# Out:
# (438, 39)

# %%
model_feat_sel = evaluate_and_log_model(
    results, LinearRegression(), xtrain_pre_sel, ytrain, xtest_pre_sel, ytest, description="Featue selection on Linear Regression"
)
# Out:
# {'description': 'Featue selection on Linear Regression', 'name': 'LinearRegression', 'cv_mean': np.float64(0.8126), 'cv_std': np.float64(0.0544), 'r2_train': 0.8395, 'r2_test': 0.8378, 'gen_err': 0.0017}

# %% [markdown]
# ## Model 3 - Ridge on selected features

# %%
alphas_list = [0, 0 , 0.1, 1, 20, 50, 200, 500, 10000]

# %%
params = {
    "alpha":alphas_list
}
print(params)
# Out:
# {'alpha': [0, 0, 0.1, 1, 20, 50, 200, 500, 10000]}

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

gscv_ridge = GridSearchCV(Ridge(random_state=42), params, cv=5, scoring="r2")
gscv_ridge.fit(xtrain_pre_sel, ytrain) # Apply this on selected features only
# Out:
# GridSearchCV(cv=5, estimator=Ridge(random_state=42),
#              param_grid={'alpha': [0, 0, 0.1, 1, 20, 50, 200, 500, 10000]},
#              scoring='r2')

# %%
gscv_ridge.best_params_
# Out:
# {'alpha': 50}

# %%
gscv_ridge.best_score_
# Out:
# np.float64(0.8150277907030189)

# %%
best_ridge = gscv_ridge.best_estimator_
best_ridge
# Out:
# Ridge(alpha=50, random_state=42)

# %%
sel_ridge = evaluate_and_log_model(
    results, best_ridge, xtrain_pre_sel, ytrain, xtest_pre_sel, ytest,
    description="Ridge on Selected Features"
)
# Out:
# {'description': 'Ridge on Selected Features', 'name': 'Ridge', 'cv_mean': np.float64(0.815), 'cv_std': np.float64(0.0485), 'r2_train': 0.8389, 'r2_test': 0.8393, 'gen_err': -0.0004}

# %% [markdown]
# ## Model 4 - Lasso on Selected features

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

gscv_lasso = GridSearchCV(Lasso(random_state=42), params, cv=5, scoring="r2")
gscv_lasso.fit(xtrain_pre_sel, ytrain)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(random_state=42),
#              param_grid={'alpha': [0, 0, 0.1, 1, 20, 50, 200, 500, 10000]},
#              scoring='r2')

# %%
gscv_lasso.best_score_
# Out:
# np.float64(0.8127563380172429)

# %%
gscv_lasso.best_params_
# Out:
# {'alpha': 200}

# %%
best_lasso = gscv_lasso.best_estimator_
best_lasso
# Out:
# Lasso(alpha=200, random_state=42)

# %%
sel_lasso = evaluate_and_log_model(
    results, best_lasso, xtrain_pre_sel, ytrain, xtest_pre_sel, ytest,
    description="Lasso on Selected features"
)
# Out:
# {'description': 'Lasso on Selected features', 'name': 'Lasso', 'cv_mean': np.float64(0.8128), 'cv_std': np.float64(0.0533), 'r2_train': 0.8394, 'r2_test': 0.8394, 'gen_err': 0.0}

# %% [markdown]
# ## Model 5 - Polynomial feature engineering with Ridge

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_ridge = make_pipeline(
    PolynomialFeatures(degree=2, include_bias=False),
    Ridge(random_state=42) # type: ignore
)

# %%
params2 = {
    "ridge__alpha":alphas_list
}

# %%
gscv_poly_ridge = GridSearchCV(poly_ridge, params2, cv=5, scoring="r2")
gscv_poly_ridge.fit(xtrain_pre_sel, ytrain)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('polynomialfeatures',
#                                         PolynomialFeatures(include_bias=False)),
#                                        ('ridge', Ridge(random_state=42))]),
#              param_grid={'ridge__alpha': [0, 0, 0.1, 1, 20, 50, 200, 500,
#                                           10000]},
#              scoring='r2')

# %%
gscv_poly_ridge.best_params_
# Out:
# {'ridge__alpha': 500}

# %%
gscv_poly_ridge.best_score_
# Out:
# np.float64(0.7849051344467123)

# %%
best_poly_ridge = gscv_poly_ridge.best_estimator_
best_poly_ridge
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(include_bias=False)),
#                 ('ridge', Ridge(alpha=500, random_state=42))])

# %%
sel_poly_ridge = evaluate_and_log_model(
    results, best_poly_ridge, xtrain_pre_sel, ytrain, xtest_pre_sel, ytest,
    description="Polynomial Ridge on Selected Features"
)
# Out:
# {'description': 'Polynomial Ridge on Selected Features', 'name': 'Pipeline', 'cv_mean': np.float64(0.7849), 'cv_std': np.float64(0.0346), 'r2_train': 0.9318, 'r2_test': 0.797, 'gen_err': 0.1348}

# %% [markdown]
# ## Model 6 - Polynomial features with Lasso

# %%
poly_lasso = make_pipeline(
    PolynomialFeatures(degree=2, include_bias=False),
    Lasso(random_state=42)
)

# %%
param3 = {
    "lasso__alpha":alphas_list
}

# %%
gscv_poly_lasso = GridSearchCV(poly_lasso, param3, cv=5, scoring="r2")
gscv_poly_lasso.fit(xtrain_pre_sel, ytrain)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('polynomialfeatures',
#                                         PolynomialFeatures(include_bias=False)),
#                                        ('lasso', Lasso(random_state=42))]),
#              param_grid={'lasso__alpha': [0, 0, 0.1, 1, 20, 50, 200, 500,
#                                           10000]},
#              scoring='r2')

# %%
gscv_poly_lasso.best_params_
# Out:
# {'lasso__alpha': 500}

# %%
gscv_poly_lasso.best_score_
# Out:
# np.float64(0.8460438503737336)

# %%
best_poly_lasso = gscv_poly_lasso.best_estimator_
best_poly_lasso
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(include_bias=False)),
#                 ('lasso', Lasso(alpha=500, random_state=42))])

# %%
sel_poly_lasso = evaluate_and_log_model(
    results, best_poly_lasso, xtrain_pre_sel, ytrain, xtest_pre_sel, ytest,
    description="Poly Lasso on selected features"
)
# Out:
# {'description': 'Poly Lasso on selected features', 'name': 'Pipeline', 'cv_mean': np.float64(0.846), 'cv_std': np.float64(0.0288), 'r2_train': 0.9469, 'r2_test': 0.8459, 'gen_err': 0.101}

# %%
res_df = pd.DataFrame(results)
res_df
# Out:
#                              description              name  cv_mean  cv_std  \
# 0             Baseline Linear Regression  LinearRegression   0.7232  0.1011
# 1  Featue selection on Linear Regression  LinearRegression   0.8126  0.0544
# 2             Ridge on Selected Features             Ridge   0.8150  0.0485
# 3             Lasso on Selected features             Lasso   0.8128  0.0533
# 4  Polynomial Ridge on Selected Features          Pipeline   0.7849  0.0346
# 5        Poly Lasso on selected features          Pipeline   0.8460  0.0288
#
#    r2_train  r2_test  gen_err
# 0    0.8576   0.6974   0.1602
# 1    0.8395   0.8378   0.0017
# 2    0.8389   0.8393  -0.0004
# 3    0.8394   0.8394   0.0000
# 4    0.9318   0.7970   0.1348
# 5    0.9469   0.8459   0.1010

# %%
sort_df = res_df.sort_values(by="gen_err")
sort_df
# Out:
#                              description              name  cv_mean  cv_std  \
# 2             Ridge on Selected Features             Ridge   0.8150  0.0485
# 3             Lasso on Selected features             Lasso   0.8128  0.0533
# 1  Featue selection on Linear Regression  LinearRegression   0.8126  0.0544
# 5        Poly Lasso on selected features          Pipeline   0.8460  0.0288
# 4  Polynomial Ridge on Selected Features          Pipeline   0.7849  0.0346
# 0             Baseline Linear Regression  LinearRegression   0.7232  0.1011
#
#    r2_train  r2_test  gen_err
# 2    0.8389   0.8393  -0.0004
# 3    0.8394   0.8394   0.0000
# 1    0.8395   0.8378   0.0017
# 5    0.9469   0.8459   0.1010
# 4    0.9318   0.7970   0.1348
# 0    0.8576   0.6974   0.1602

# %%
sort_df.to_csv("evaluation.csv", index=False)

# %% [markdown]
# ## Step 6 - Evaluate the model

# %%
# Evaluate in detail
from sklearn.metrics import (
    root_mean_squared_error,
    mean_absolute_error,
    mean_absolute_percentage_error,
    r2_score
)

def evaluate_model(model, x, y):
    #Predict results for x
    ypred = model.predict(x)
    # Get the metrices
    rmse = root_mean_squared_error(y, ypred)
    mae = mean_absolute_error(y, ypred)
    mape = mean_absolute_percentage_error(y, ypred)
    r2 = r2_score(y, ypred)
    # Print the results
    print(f"RMSE : {rmse:.2f}")
    print(f"MAE : {mae:.2f}")
    print(f"MAPE : {mape:.2%}")
    print(f"R2 : {r2:.2%}")

# %%
evaluate_model(sel_poly_ridge, xtrain_pre_sel, ytrain)
# Out:
# RMSE : 21039.18
# MAE : 14146.70
# MAPE : 8.46%
# R2 : 93.18%

# %%
evaluate_model(sel_poly_ridge, xtest_pre_sel, ytest)
# Out:
# RMSE : 34485.19
# MAE : 24072.18
# MAPE : 15.55%
# R2 : 79.70%

# %% [markdown]
# ## Out of Sample Prediction

# %%
xnew = pd.read_csv("testing_set.csv", na_values=["","NA"], keep_default_na=False)
xnew
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0            Lvl    AllPub  ...         120        0    NaN  MnPrv
# 1            Lvl    AllPub  ...           0        0    NaN    NaN
# 2            Lvl    AllPub  ...           0        0    NaN  MnPrv
# 3            Lvl    AllPub  ...           0        0    NaN    NaN
# 4            HLS    AllPub  ...         144        0    NaN    NaN
# ...          ...       ...  ...         ...      ...    ...    ...
# 1454         Lvl    AllPub  ...           0        0    NaN    NaN
# 1455         Lvl    AllPub  ...           0        0    NaN    NaN
# 1456         Lvl    AllPub  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0            NaN       0      6    2010        WD         Normal
# 1           Gar2   12500      6    2010        WD         Normal
# 2            NaN       0      3    2010        WD         Normal
# 3            NaN       0      6    2010        WD         Normal
# 4            NaN       0      1    2010        WD         Normal
# ...          ...     ...    ...     ...       ...            ...
# 1454         NaN       0      6    2006        WD         Normal
# 1455         NaN       0      4    2006        WD        Abnorml
# 1456         NaN       0      9    2006        WD        Abnorml
# 1457        Shed     700      7    2006        WD         Normal
# 1458         NaN       0     11    2006        WD         Normal
#
# [1459 rows x 80 columns]

# %%
xnew_pre = pre.transform(xnew) # type: ignore
xnew_pre
# Out:
#       num__MSSubClass  num__LotFrontage  num__LotArea  num__OverallQual  \
# 0           -0.872425          0.424393      0.083219         -0.832137
# 1           -0.872425          0.467730      0.317291         -0.103393
# 2            0.068721          0.164372      0.278619         -0.832137
# 3            0.068721          0.337719     -0.062269         -0.103393
# 4            1.480440         -1.179069     -0.502360          1.354094
# ...               ...               ...           ...               ...
# 1454         2.421586         -2.132479     -0.773955         -1.560880
# 1455         2.421586         -2.132479     -0.777672         -1.560880
# 1456        -0.872425          3.891339      0.824640         -0.832137
# 1457         0.656937         -0.355670     -0.021295         -0.832137
# 1458         0.068721          0.164372     -0.093331          0.625350
#
#       num__OverallCond  num__YearBuilt  num__YearRemodAdd  num__MasVnrArea  \
# 0             0.402383       -0.348885          -1.160582        -0.574378
# 1             0.402383       -0.447829          -1.306022         0.004820
# 2            -0.517607        0.838441           0.633182        -0.574378
# 3             0.402383        0.871422           0.633182        -0.467119
# 4            -0.517607        0.673535           0.342302        -0.574378
# ...                ...             ...                ...              ...
# 1454          1.322374       -0.052054          -0.724261        -0.574378
# 1455         -0.517607       -0.052054          -0.724261        -0.574378
# 1456          1.322374       -0.381866           0.536222        -0.574378
# 1457         -0.517607        0.673535           0.342302        -0.574378
# 1458         -0.517607        0.706516           0.439262        -0.070261
#
#       num__BsmtFinSF1  num__BsmtFinSF2  ...  cat__GarageType  \
# 0            0.044204         0.686611  ...        -0.680759
# 1            1.016489        -0.272009  ...        -0.680759
# 2            0.734419        -0.272009  ...        -0.680759
# 3            0.330547        -0.272009  ...        -0.680759
# 4           -0.393859        -0.272009  ...        -0.680759
# ...               ...              ...  ...              ...
# 1454        -0.955862        -0.272009  ...        -0.680759
# 1455        -0.417365        -0.272009  ...         1.027266
# 1456         1.659694        -0.272009  ...         1.596608
# 1457        -0.235729        -0.272009  ...        -0.680759
# 1458         0.663902        -0.272009  ...        -0.680759
#
#       cat__GarageFinish  cat__GarageQual  cat__GarageCond  cat__PavedDrive  \
# 0              0.971066         0.209088         0.187974         0.281373
# 1              0.971066         0.209088         0.187974         0.281373
# 2             -1.488486         0.209088         0.187974         0.281373
# 3             -1.488486         0.209088         0.187974         0.281373
# 4             -0.258710         0.209088         0.187974         0.281373
# ...                 ...              ...              ...              ...
# 1454           0.971066         0.209088         0.187974         0.281373
# 1455           0.971066         0.209088         0.187974         0.281373
# 1456           0.971066         0.209088         0.187974         0.281373
# 1457           0.971066         0.209088         0.187974         0.281373
# 1458          -1.488486         0.209088         0.187974         0.281373
#
#       cat__PoolQC  cat__Fence  cat__MiscFeature  cat__SaleType  \
# 0        0.044281    0.265798          0.059456       0.319937
# 1        0.044281    0.265798        -20.195052       0.319937
# 2        0.044281    0.265798          0.059456       0.319937
# 3        0.044281    0.265798          0.059456       0.319937
# 4        0.044281    0.265798          0.059456       0.319937
# ...           ...         ...               ...            ...
# 1454     0.044281    0.265798          0.059456       0.319937
# 1455     0.044281    0.265798          0.059456       0.319937
# 1456     0.044281    0.265798          0.059456       0.319937
# 1457     0.044281    0.265798          0.059456       0.319937
# 1458     0.044281    0.265798          0.059456       0.319937
#
#       cat__SaleCondition
# 0               0.206519
# 1               0.206519
# 2               0.206519
# 3               0.206519
# 4               0.206519
# ...                  ...
# 1454            0.206519
# 1455           -3.386035
# 1456           -3.386035
# 1457            0.206519
# 1458            0.206519
#
# [1459 rows x 79 columns]

# %%
xnew_pre_sel = sel.transform(xnew_pre)
xnew_pre_sel
# Out:
# array([[-0.87242495,  0.08321912, -0.83213659, ...,  0.20908829,
#          0.18797359,  0.20651914],
#        [-0.87242495,  0.31729148, -0.10339315, ...,  0.20908829,
#          0.18797359,  0.20651914],
#        [ 0.06872116,  0.27861865, -0.83213659, ...,  0.20908829,
#          0.18797359,  0.20651914],
#        ...,
#        [-0.87242495,  0.82463998, -0.83213659, ...,  0.20908829,
#          0.18797359, -3.38603512],
#        [ 0.65693749, -0.02129484, -0.83213659, ...,  0.20908829,
#          0.18797359,  0.20651914],
#        [ 0.06872116, -0.09333072,  0.62535029, ...,  0.20908829,
#          0.18797359,  0.20651914]], shape=(1459, 39))

# %%
preds = sel_poly_ridge.predict(xnew_pre_sel)
preds
# Out:
# array([145314.31937471, 143557.09646739, 169735.93839256, ...,
#        172982.09251557, 144806.43372817, 229596.24161267], shape=(1459,))

# %%
xnew["SalesPrice_pred"] = preds.round(2)
xnew
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN        Gar2   12500
# 2            Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            HLS    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1454         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalesPrice_pred
# 0         6   2010        WD         Normal        145314.32
# 1         6   2010        WD         Normal        143557.10
# 2         3   2010        WD         Normal        169735.94
# 3         6   2010        WD         Normal        178145.99
# 4         1   2010        WD         Normal        190692.21
# ...     ...    ...       ...            ...              ...
# 1454      6   2006        WD         Normal        111796.37
# 1455      4   2006        WD        Abnorml         96871.20
# 1456      9   2006        WD        Abnorml        172982.09
# 1457      7   2006        WD         Normal        144806.43
# 1458     11   2006        WD         Normal        229596.24
#
# [1459 rows x 81 columns]

# %%
xnew.to_csv("results.csv", index=False)

# %% [markdown]
# ## Step 7 - Save Preprocessor, Selector and Model in Joblib Format

# %%
import joblib

joblib.dump(pre, "preprocessor.joblib")
# Out:
# ['preprocessor.joblib']

# %%
joblib.dump(sel, "selector.joblib")
# Out:
# ['selector.joblib']

# %%
joblib.dump(sel_poly_ridge, "model.joblib")
# Out:
# ['model.joblib']

# %%
p = joblib.load("preprocessor.joblib")
p
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['MSSubClass', 'LotFrontage', 'LotArea',
#                                   'OverallQual', 'OverallCond', 'YearBuilt',
#                                   'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#                                   'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#                                   '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#                                   'GrLivArea', 'BsmtFullBath', '...
#                                  ['MSZoning', 'Street', 'Alley', 'LotShape',
#                                   'LandContour', 'Utilities', 'LotConfig',
#                                   'LandSlope', 'Neighborhood', 'Condition1',
#                                   'Condition2', 'BldgType', 'HouseStyle',
#                                   'RoofStyle', 'RoofMatl', 'Exterior1st',
#                                   'Exterior2nd', 'MasVnrType', 'ExterQual',
#                                   'ExterCond', 'Foundation', 'BsmtQual',
#                                   'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#                                   'BsmtFinType2', 'Heating', 'HeatingQC',
#                                   'CentralAir', 'Electrical', ...])])

# %%
s = joblib.load("selector.joblib")
s
# Out:
# SequentialFeatureSelector(estimator=LinearRegression())

# %%
m = joblib.load("model.joblib")
m
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(include_bias=False)),
#                 ('ridge', Ridge(alpha=500, random_state=42))])
